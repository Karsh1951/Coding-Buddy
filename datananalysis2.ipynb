# %% [markdown]
# <a href="https://colab.research.google.com/github/Karsh1951/Coding-Buddy/blob/master/datananalysis2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
#filtering developers with the highest salary
high_salary = (df ['ConvertedComp'] > 70000)
df.loc[high_salary,['Country','LanguageWorkedWith','ConvertedComp']]
# Out:
#                    Country                                 LanguageWorkedWith  \
# Respondent
# 8            United States                                         Python;SQL
# 16          United Kingdom  Bash/Shell/PowerShell;HTML/CSS;Java;JavaScript...
# 17           United States              C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 18           United States                Bash/Shell/PowerShell;HTML/CSS;Perl
# 19           United States  Bash/Shell/PowerShell;C#;HTML/CSS;JavaScript;S...
# ...                    ...                                                ...
# 6848         United States             Assembly;C;C++;Go;Java;PHP;Python;Ruby
# 6863               Germany  Bash/Shell/PowerShell;Java;Kotlin;Objective-C;...
# 6869        United Kingdom                      Bash/Shell/PowerShell;C#;Java
# 6870         United States                  HTML/CSS;Java;JavaScript;Ruby;SQL
# 6890         United States                           Go;JavaScript;TypeScript
#
# ...

# %%
#to get the specific countries that are in the dataset
countries =['India', 'Canada','South Africa']
filt = df['Country'].isin(countries)
df.loc[filt,'Country']
# Out:
# Respondent
# 7        India
# 22       India
# 26      Canada
# 32      Canada
# 51      Canada
#          ...
# 6884     India
# 6886     India
# 6887     India
# 6889     India
# 6891     India
# Name: Country, Length: 1130, dtype: object

# %%
#we want to filter out the language worked with where language worked with is only python using a string method
filt = df['LanguageWorkedWith'].str.contains('Python',na = False)
df.loc[filt,'LanguageWorkedWith']
# Out:
# Respondent
# 3                                Objective-C;Python;Swift
# 8                                              Python;SQL
# 10                    HTML/CSS;Java;JavaScript;Python;SQL
# 13                                    C;JavaScript;Python
# 15       Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                               ...
# 6875        HTML/CSS;JavaScript;PHP;Python;SQL;TypeScript
# 6877                   HTML/CSS;JavaScript;PHP;Python;SQL
# 6878    C;C++;HTML/CSS;Java;JavaScript;Objective-C;PHP...
# 6881                              Java;Python;R;Scala;SQL
# 6883                                Assembly;C;C++;Python
# Name: LanguageWorkedWith, Length: 3057, dtype: object

# %%
df = pd.read_csv('/content/survey_results_public.csv',index_col='Respondent')
df.shape
# Out:
# (6863, 60)

# %%
#to get all the info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6863 entries, 1 to 6891
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    6863 non-null   object
#  1   Hobbyist                      6863 non-null   object
#  2   Age                           5968 non-null   float64
#  3   Age1stCode                    6812 non-null   object
#  4   CompFreq                      5049 non-null   object
#  5   CompTotal                     4591 non-null   float64
#  6   ConvertedComp                 4578 non-null   float64
#  7   Country                       6863 non-null   object
#  8   CurrencyDesc                  5650 non-null   object
#  9   CurrencySymbol                5650 non-null   object
#  10  DatabaseDesireNextYear        5200 non-null   object
#  11  DatabaseWorkedWith            5900 non-null   object
# ...

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61 )

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 6887                           I am a developer by profession      Yes   NaN
# 6888                           I am a developer by profession      Yes  32.0
# 6889                           I am a developer by profession       No  31.0
# 6890                           I am a developer by profession      Yes  36.0
# 6891                           I am a developer by profession      Yes  29.0
#
# ...

# %%
schema_df =pd.read_csv('/content/survey_results_schema.csv',index_col='Column')
schema_df
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
pd.set_option('display.max_columns',61)

# %%
df.tail(20)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 42685       43460                     I am a developer by profession      Yes
# 42686       43461                        I code primarily as a hobby      Yes
# 42687       43462             I am a student who is learning to code      Yes
# 42688       43463                     I am a developer by profession      Yes
# 42689       43464                     I am a developer by profession      Yes
# 42690       43465             I am a student who is learning to code      Yes
# 42691       43467                     I am a developer by profession       No
# 42692       43468  I used to be a developer by profession, but no...      Yes
# 42693       43469             I am a student who is learning to code      Yes
# 42694       43470                     I am a developer by profession      Yes
# 42695       43472                     I am a developer by profession      Yes
# ...

# %%
df.tail(10)
# Out:
#       Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 6853        6882  I am a developer by profession      Yes  32.0         16
# 6854        6883  I am a developer by profession      Yes  35.0          8
# 6855        6884  I am a developer by profession      Yes  27.0         18
# 6856        6885  I am a developer by profession      Yes  31.0         14
# 6857        6886  I am a developer by profession      Yes  23.0         15
# 6858        6887  I am a developer by profession      Yes   NaN         18
# 6859        6888  I am a developer by profession      Yes  32.0         20
# 6860        6889  I am a developer by profession       No  31.0         21
# 6861        6890  I am a developer by profession      Yes  36.0         16
# 6862        6891  I am a developer by profession      Yes  29.0         13
#
#      CompFreq  CompTotal  ConvertedComp             Country  \
# 6853   Yearly    55000.0        59454.0               Italy
# ...

# %%
#grabbinng all responce for hobyst column
df['Hobbyist']
# Out:
# 0        Yes
# 1         No
# 2        Yes
# 3        Yes
# 4        Yes
#         ...
# 42700    Yes
# 42701     No
# 42702    Yes
# 42703    Yes
# 42704     No
# Name: Hobbyist, Length: 42705, dtype: object

# %%
#Getting the number of responce for those who answered yes and those who answered NO
df['Hobbyist'].value_counts()
# Out:
# Yes    33491
# No      9190
# Name: Hobbyist, dtype: int64

# %%
#grabbing a specific columns and specific rows(it will give all of the responce from the targeted respondence)
df.loc[0]
# Out:
# Respondent                                                                      1
# MainBranch                                         I am a developer by profession
# Hobbyist                                                                      Yes
# Age                                                                           NaN
# Age1stCode                                                                     13
# CompFreq                                                                  Monthly
# CompTotal                                                                     NaN
# ConvertedComp                                                                 NaN
# Country                                                                   Germany
# CurrencyDesc                                                        European Euro
# CurrencySymbol                                                                EUR
# ...

# %%
#to get result only for hobyst question
df.loc[0,'Hobbyist']
# Out:
# 'Yes'

# %%
#getting the result for the first three rows 
df.loc[[0,1,2,3],'Hobbyist']
# Out:
# 0    Yes
# 1     No
# 2    Yes
# 3    Yes
# Name: Hobbyist, dtype: object

# %%
#to get the number of columns
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
#specifying the range of columns we neeed (slicing)
df.loc[0:2,'Hobbyist':'Employment' ]
# Out:
#   Hobbyist  Age Age1stCode CompFreq  CompTotal  ConvertedComp  \
# 0      Yes  NaN         13  Monthly        NaN            NaN
# 1       No  NaN         19      NaN        NaN            NaN
# 2      Yes  NaN         15      NaN        NaN            NaN
#
#               Country    CurrencyDesc CurrencySymbol DatabaseDesireNextYear  \
# 0             Germany   European Euro            EUR   Microsoft SQL Server
# 1      United Kingdom  Pound sterling            GBP                    NaN
# 2  Russian Federation             NaN            NaN                    NaN
#
#                           DatabaseWorkedWith  \
# 0  Elasticsearch;Microsoft SQL Server;Oracle
# 1                                        NaN
# 2                                        NaN
#
#                                              DevType  \
# 0  Developer, desktop or enterprise applications;...
# 1            Developer, full-stack;Developer, mobile
# 2                                                NaN
#
# ...
